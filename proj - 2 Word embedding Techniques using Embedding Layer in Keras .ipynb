# %%
import tensorflow as tf
# print(tf.__version__)

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
#### sentences
sent=["The world is a better place",
      "Marvel series is my favourite movie",
      "I like DC movies",
      "the cat is eating the food",
      "Tom and Jerry is my favourite movie",
      "Python is my favourite programming language"
      ]

# %%
sent
# Out:
# ['The world is a better place',
#  'Marvel series is my favourite movie',
#  'I like DC movies',
#  'the cat is eating the food',
#  'Tom and Jerry is my favourite movie',
#  'Python is my favourite programming language']

# %%
#### vocubulary size
voc_size = 500

# %% [markdown]
# # One Hot Representation

# %%
onehot_res = [one_hot(words,voc_size) for words in sent]
onehot_res
# Out:
# [[454, 264, 349, 111, 194, 245],
#  [436, 367, 349, 62, 68, 396],
#  [416, 238, 82, 372],
#  [454, 208, 349, 87, 454, 297],
#  [239, 390, 498, 349, 62, 68, 396],
#  [423, 349, 62, 68, 24, 433]]

# %% [markdown]
# # Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
## prepadding
sent_length = 8
embedded_docs = pad_sequences(onehot_res,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[  0   0 454 264 349 111 194 245]
#  [  0   0 436 367 349  62  68 396]
#  [  0   0   0   0 416 238  82 372]
#  [  0   0 454 208 349  87 454 297]
#  [  0 239 390 498 349  62  68 396]
#  [  0   0 423 349  62  68  24 433]]

# %%
## 10 feature dimensions
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,10,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 8, 10)             5000
#
# =================================================================
# Total params: 5000 (19.53 KB)
# Trainable params: 5000 (19.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
## 'The world is a better place'
embedded_docs[0]
# Out:
# array([  0,   0, 454, 264, 349, 111, 194, 245])

# %%
print(model.predict(embedded_docs[0]))
# Out:
# 1/1 [==============================] - 0s 45ms/step
# [[ 0.01957956  0.0435085   0.00912322  0.04572562  0.03584453  0.0244208
#   -0.02145196 -0.03818391  0.01192585  0.00257744]
#  [ 0.01957956  0.0435085   0.00912322  0.04572562  0.03584453  0.0244208
#   -0.02145196 -0.03818391  0.01192585  0.00257744]
#  [-0.01507466 -0.03089141  0.01244392  0.03266069  0.00618977 -0.01361569
#    0.04422916 -0.02898675 -0.04096063  0.03094826]
#  [ 0.00697607 -0.02183778  0.02112234  0.02223383  0.01006684 -0.01379486
#    0.04244718 -0.012852   -0.01935415  0.04991398]
#  [ 0.01022596 -0.00223    -0.00395475 -0.04742975 -0.02258097  0.01430656
#   -0.01645232 -0.03282805 -0.01049179 -0.00405073]
#  [ 0.03557259  0.019025    0.01802126 -0.02991667  0.04858769 -0.04907061
#    0.02661267  0.04020769 -0.04647261  0.03522107]
#  [-0.04611126  0.03658127  0.00929661  0.04621654  0.04701335  0.00378732
#    0.00222442 -0.03325278  0.01169875 -0.03562545]
#  [-0.0232056   0.01301574 -0.01615524  0.01082623  0.00571573  0.04308898
#    0.00398607  0.04726027  0.01077778  0.02563838]]

# %%
print(model.predict(embedded_docs))
# Out:
# 1/1 [==============================] - 0s 39ms/step
# [[[ 0.01957956  0.0435085   0.00912322  0.04572562  0.03584453
#     0.0244208  -0.02145196 -0.03818391  0.01192585  0.00257744]
#   [ 0.01957956  0.0435085   0.00912322  0.04572562  0.03584453
#     0.0244208  -0.02145196 -0.03818391  0.01192585  0.00257744]
#   
#   [ 0.02173814  0.02001842  0.00977713  0.00311682 -0.01095258
#     0.01587087 -0.01921707  0.04320901 -0.01456987  0.04394842]
#   [-0.01507466 -0.03089141  0.01244392  0.03266069  0.00618977
#    -0.01361569  0.04422916 -0.02898675 -0.04096063  0.03094826]
#   [ 0.00434582 -0.03201199 -0.03577255  0.01385117 -0.0179178
#    -0.03817625 -0.04013854 -0.00467144 -0.04176861  0.00448904]]
#
#  [[ 0.01957956  0.0435085   0.00912322  0.04572562  0.03584453
#     0.0244208  -0.02145196 -0.03818391  0.01192585  0.00257744]
#   [-0.02826567 -0.0024133  -0.01219063  0.01718947  0.04144077
#    -0.0009613  -0.02239125  0.00967914  0.03283396 -0.01832317]
#   [ 0.02351971 -0.00153158  0.04025758  0.04570786  0.03776283
#     0.04552844 -0.0467221   0.01787112 -0.00923612 -0.02014254]
#   [-0.01905531 -0.01384562  0.0454202  -0.03432909  0.00546923
#    -0.00328688  0.04381765  0.0055614   0.03087148 -0.02517123]
#   [ 0.01022596 -0.00223    -0.00395475 -0.04742975 -0.02258097
#     0.01430656 -0.01645232 -0.03282805 -0.01049179 -0.00405073]
#   [-0.04961997  0.04031739 -0.02843367  0.00462247 -0.03322367
#    -0.02220448  0.04489351  0.02575267  0.04456372  0.04866565]
#   [ 0.01289393  0.03486091 -0.04985135  0.04496082  0.02497119
#     0.00918019  0.03278948 -0.03594991  0.03717034  0.04337002]
#   [ 0.03169396 -0.04785356  0.01764471  0.04451456 -0.03778132
#    -0.01608576  0.00514394  0.03595725 -0.02737421  0.02127833]]
#
#  [[ 0.01957956  0.0435085   0.00912322  0.04572562  0.03584453
#     0.0244208  -0.02145196 -0.03818391  0.01192585  0.00257744]
#   [ 0.01957956  0.0435085   0.00912322  0.04572562  0.03584453
#     0.0244208  -0.02145196 -0.03818391  0.01192585  0.00257744]
#   [ 0.02596499  0.04467172 -0.00104276 -0.01118592 -0.00440472
#    -0.00669627  0.02569039  0.03336037  0.00243924  0.01609408]
#   [ 0.01022596 -0.00223    -0.00395475 -0.04742975 -0.02258097
#     0.01430656 -0.01645232 -0.03282805 -0.01049179 -0.00405073]
#   [-0.04961997  0.04031739 -0.02843367  0.00462247 -0.03322367
#    -0.02220448  0.04489351  0.02575267  0.04456372  0.04866565]
#   [ 0.01289393  0.03486091 -0.04985135  0.04496082  0.02497119
#     0.00918019  0.03278948 -0.03594991  0.03717034  0.04337002]
#   [-0.00740797 -0.04036256  0.00782277  0.03773007 -0.00557278
#     0.02283111 -0.03988043 -0.02548748 -0.04343439  0.03336674]
#   [-0.04842837 -0.02684507 -0.02646985 -0.01939561  0.00573113
#     0.04583872  0.02592203  0.04434072 -0.0253821  -0.01193628]]]

# %%
embedded_docs[0]
# Out:
# array([  0,   0, 454, 264, 349, 111, 194, 245])
